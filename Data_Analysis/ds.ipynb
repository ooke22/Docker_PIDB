# %%
import pandas as pd 
import requests

# %%
url = 'http://127.0.0.1:8000/test/v3/sensors/?batch_location=N&process_id=SP001&page_size=200'
response = requests.get(url)

if response.status_code == 200:
    data = response.json()['results']
else:
    print("API request failed with status code:", response.status_code)

# %%
df = pd.DataFrame(data)
df
# Out:
#     batch_location  batch_id  total_wafers  total_sensors batch_label  \
# 0                N        21            16            220
# 1                N        21            16            220
# 2                N        21            16            220
# 3                N        21            16            220
# 4                N        21            16            220
# ..             ...       ...           ...            ...         ...
# 195              N        21            16            220
# 196              N        21            16            220
# 197              N        21            16            220
# 198              N        21            16            220
# 199              N        21            16            220
#
#     batch_description  wafer_id wafer_label wafer_description wafer_design_id  \
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ..                ...       ...         ...               ...             ...
# 195                           1
# 196                           1
# 197                           1
# 198                           1
# 199                           1
#
#     wafer_build_time  sensor_id sensor_label sensor_description  \
# 0                           159
# 1                           191
# 2                            95
# 3                           143
# 4                           111
# ..               ...        ...          ...                ...
# 195                           7
# 196                          15
# 197                          31
# 198                          63
# 199                         127
#
#                                        wafer_processes images
# 0    [{'process_id': 'Test 2', 'description': 'Fron...     []
# 1    [{'process_id': 'Test 2', 'description': 'Fron...     []
# 2    [{'process_id': 'Test 2', 'description': 'Fron...     []
# 3    [{'process_id': 'Test 2', 'description': 'Fron...     []
# 4    [{'process_id': 'Test 2', 'description': 'Fron...     []
# ..                                                 ...    ...
# 195  [{'process_id': 'Test 2', 'description': 'Fron...     []
# 196  [{'process_id': 'Test 2', 'description': 'Fron...     []
# 197  [{'process_id': 'Test 2', 'description': 'Fron...     []
# 198  [{'process_id': 'Test 2', 'description': 'Fron...     []
# 199  [{'process_id': 'Test 2', 'description': 'Fron...     []
#
# [200 rows x 16 columns]
